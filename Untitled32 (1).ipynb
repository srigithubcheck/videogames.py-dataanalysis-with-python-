# %%
import pandas as pd

# %%
df = pd.read_csv("vgchartz-2024.csv")

# %%
df
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %% [markdown]
# how to analysize data frames

# %% [markdown]
# .head()

# %%
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %% [markdown]
# .Shape

# %% [markdown]
# it shows the total no of rows and no of coloumns of data frame

# %%
df.shape
# Out:
# (64016, 14)

# %% [markdown]
# **.Index**

# %% [markdown]
# **it shows index of the dataframe**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=64016, step=1)

# %% [markdown]
# **.coloumns**

# %% [markdown]
# **it shows the columns of dataframe**

# %%
df.columns
# Out:
# Index(['img', 'title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'total_sales', 'na_sales', 'jp_sales', 'pal_sales',
#        'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %% [markdown]
# **.datatypes**

# %% [markdown]
# **it shows the datatype of each column**

# %%
df.dtypes
# Out:
# img              object
# title            object
# console          object
# genre            object
# publisher        object
# developer        object
# critic_score    float64
# total_sales     float64
# na_sales        float64
# jp_sales        float64
# pal_sales       float64
# other_sales     float64
# release_date     object
# last_update      object
# dtype: object

# %% [markdown]
# **.unique**

# %% [markdown]
# **in columns, it shows only unique values**

# %%
df['developer'].unique()
# Out:
# array(['Rockstar North', 'Treyarch', 'Infinity Ward', ...,
#        'Different Tales', '4D Door Games', 'InvertMouse'], dtype=object)

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# ...

# %% [markdown]
# **.count**

# %% [markdown]
# it shows all null values in each column, it can be applied on whole dataframe

# %%
df.count()
# Out:
# img             64016
# title           64016
# console         64016
# genre           64016
# publisher       64016
# developer       63999
# critic_score     6678
# total_sales     18922
# na_sales        12637
# jp_sales         6726
# pal_sales       12824
# other_sales     15128
# release_date    56965
# last_update     17879
# dtype: int64

# %% [markdown]
# **.value_counts**

# %% [markdown]
# **in a column, it shows all the unique values with their count.it can be applied on single coloum only**

# %%
df.value_counts()
# Out:
# img                                            title                                 console  genre             publisher                       developer                            critic_score  total_sales  na_sales  jp_sales  pal_sales  other_sales  release_date  last_update
# /games/boxart/1410926ccc.jpg                   The Eye of Judgment                   PS3      Strategy          Sony Computer Entertainment     SCE Japan Studio                     7.5           0.34         0.28      0.02      0.00       0.03         2007-10-24    2018-09-16     1
# /games/boxart/full_7208237AmericaFrontccc.jpg  Metal Gear Solid: Snake Eater 3D      3DS      Action-Adventure  Konami Digital Entertainment    Konami Computer Entertainment Japan  7.9           0.39         0.15      0.10      0.12       0.02         2012-02-21    2018-08-05     1
# ...

# %% [markdown]
# **.info**

# %% [markdown]
# **provides basic information on dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB

# %% [markdown]
# **Q1)Find all the unique 'developer' values in the data**

# %%
df['developer'].unique()
# Out:
# array(['Rockstar North', 'Treyarch', 'Infinity Ward', ...,
#        'Different Tales', '4D Door Games', 'InvertMouse'], dtype=object)

# %%
df['developer'].value_counts()
# Out:
# developer
# Unknown             4435
# Konami               976
# Sega                 915
# Capcom               870
# Namco                489
#                     ...
# Solutions 2 Go         1
# Whampashimash          1
# Redwind Software       1
# Iron Square            1
# Paretto                1
# Name: count, Length: 8862, dtype: int64

# %% [markdown]
# **Q2)Find the number of times when genre is action**

# %%
df[df['genre'] == "Action"]
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 13                      /games/boxart/3570928ccc.jpg
# ...                                              ...
# 24635      /games/boxart/full_8291617PALFrontccc.png
# 24636    /games/boxart/full_7297855JapanFrontccc.jpg
# 24637   /games/boxart/full_452226AmericaFrontccc.png
# 24638                      /games/boxart/default.jpg
# 24639   /games/boxart/full_286902AmericaFrontccc.png
#
#                                   title console   genre       publisher  \
# 0                    Grand Theft Auto V     PS3  Action  Rockstar Games
# 1                    Grand Theft Auto V     PS4  Action  Rockstar Games
# 2           Grand Theft Auto: Vice City     PS2  Action  Rockstar Games
# ...

# %% [markdown]
# **Q3)Find out all the null values**

# %%
df.isnull().sum()
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
df.notnull().sum()
# Out:
# img             64016
# title           64016
# console         64016
# genre           64016
# publisher       64016
# developer       63999
# critic_score     6678
# total_sales     18922
# na_sales        12637
# jp_sales         6726
# pal_sales       12824
# other_sales     15128
# release_date    56965
# last_update     17879
# dtype: int64

# %% [markdown]
# **Q4)Rename the column of the dataframe "critic score" to "rating"**

# %%
df.rename(columns = {'critic_score' : 'Rating'}, inplace = True)

# %%
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  Rating  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North     9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North     9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North     9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North     NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch     8.1        15.09
#
# ...

# %%
df[(df['Rating'] == 9.4) & (df['publisher'] == "Rockstar games")]
# Out:
# Empty DataFrame
# Columns: [img, title, console, genre, publisher, developer, Rating, total_sales, na_sales, jp_sales, pal_sales, other_sales, release_date, last_update]
# Index: []

# %% [markdown]
# ** what is the mean of total sales **

# %%
df.total_sales.mean()
# Out:
# 0.34911267307895577

# %% [markdown]
# **what are the games that released on the year of 2013**

# %%
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %%
df.groupby('title')['na_sales'].max()
# Out:
# title
# "Nuke It"                      NaN
# #DRIVE Rally                   NaN
# #IDARB                         NaN
# #killallzombies                NaN
# '70s Robot Anime: Geppy-X      NaN
#                                 ..
# yOm                            NaN
# yOm_fury                       NaN
# ¡Shin Chan Flipa en colores!   NaN
# じんるいのみなさまへ                     NaN
# レミロア~少女と異世界と魔導書                NaN
# Name: na_sales, Length: 39798, dtype: float64

# %%
df.groupby('title').max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
df
